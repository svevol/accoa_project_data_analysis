# %%
import altair as alt
import pandas as pd
import numpy as np

# %%
data = pd.read_excel("../data/enrichment/pathway_enrichment.xlsx", sheet_name="for_analysis")

# %%
data.head()
# Out:
#                                     Pathways  p-values Abundance    Strain  \
# 0  Purine Riboucleotide De Novo Biosynthesis  0.000308        up  accAgltA
# 1                   Carbohydrate Degradation  0.000393        up  accAgltA
# 2                    Carboxylate Degradation  0.000850        up  accAgltA
# 3                          Sugar Degradation  0.000983        up  accAgltA
# 4                    Amino Acid Biosynthesis  0.001607        up  accAgltA
#
#                                              Matches
# 0  gmk // guaA // guaB // adk // purB // purE // ...
# 1  PP_1776 // algC // pgm // pykA // eno // pgk /...
# 2  purT // acsA-I // PP_2217 // PP_2215 // bktB /...
# 3  PP_1776 // algC // pgm // pykA // eno // pgk /...
# 4  argJ // argA // carA // argB // argC // astC /...

# %%
data["num_matches"] = data["Matches"].str.count("//") + 1
data["-logP"] = -np.log10(data["p-values"])
data["Abundance"] = np.where(data["Abundance"] == "up", "increased", "decreased")

# %%
data.head()
# Out:
#                                     Pathways  p-values  Abundance    Strain  \
# 0  Purine Riboucleotide De Novo Biosynthesis  0.000308  increased  accAgltA
# 1                   Carbohydrate Degradation  0.000393  increased  accAgltA
# 2                    Carboxylate Degradation  0.000850  increased  accAgltA
# 3                          Sugar Degradation  0.000983  increased  accAgltA
# 4                    Amino Acid Biosynthesis  0.001607  increased  accAgltA
#
#                                              Matches  num_matches     -logP
# 0  gmk // guaA // guaB // adk // purB // purE // ...            8  3.511449
# 1  PP_1776 // algC // pgm // pykA // eno // pgk /...           19  3.405607
# 2  purT // acsA-I // PP_2217 // PP_2215 // bktB /...           25  3.070581
# 3  PP_1776 // algC // pgm // pykA // eno // pgk /...           17  3.007446
# 4  argJ // argA // carA // argB // argC // astC /...           46  2.794097

# %% [markdown]
# # Generate enrichment plot

# %%
strain = "accAgltA"
plot_df = data.query(f"Strain == '{strain}'")
base_chart = (
    alt.Chart(plot_df, title=f"Enriched patwhays in {strain}")
              .encode(
                  y=alt.Y("Pathways", sort="-x", axis=alt.Axis(title=None)),
                  x=alt.X("-logP", axis=alt.Axis(grid=False)),
                  facet=alt.Facet("Abundance", columns=2, header=alt.Header(labelFontSize=18, titleFontSize=18)),
                  color=alt.condition("datum.Abundance == 'increased'", alt.value("crimson"), alt.value("navy"))
              )
)

(base_chart.mark_circle()
.encode(size="num_matches")
.resolve_scale(y="independent", x="independent")
.configure_axisY(labelLimit=400).configure_axis(
    labelFontSize=15,
    titleFontSize=15,
).configure_view(
    strokeOpacity=0
)
)
# Out:
# alt.Chart(...)

# %% [markdown]
# # Generate enrichment plot for top 10 hits

# %%
strain = "accAgltA"
plot_df = data.query(f"Strain == '{strain}'")
increased = plot_df.query(f"Abundance == 'increased'").sort_values(by=['-logP'],ascending=False).head(10)
decreased = plot_df.query(f"Abundance == 'decreased'").sort_values(by=['-logP'],ascending=False).head(10)
plot_df = pd.concat([increased,decreased])
base_chart = (
    alt.Chart(plot_df, title=f"Enriched patwhays in {strain}")
              .encode(
                  y=alt.Y("Pathways", sort="-x", axis=alt.Axis(title=None)),
                  x=alt.X("-logP", axis=alt.Axis(grid=False)),
                  facet=alt.Facet("Abundance", columns=2, header=alt.Header(labelFontSize=18, titleFontSize=18)),
                  color=alt.condition("datum.Abundance == 'increased'", alt.value("crimson"), alt.value("navy"))
              )
)

(base_chart.mark_circle()
.encode(size="num_matches")
.resolve_scale(y="independent", x="independent")
.configure_axisY(labelLimit=400).configure_axis(
    labelFontSize=15,
    titleFontSize=15,
).configure_view(
    strokeOpacity=0
)
)
# Out:
# alt.Chart(...)
